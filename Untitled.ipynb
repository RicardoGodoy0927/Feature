# %%
import re
import pandas as pd

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')

from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### Punto 1: Pre-Procesamiento
# ### Leer el archivo dialogos.csv usando pandas
# ### Crear una nueva columna con el texto en minúscula, sin caracteres especiales ni números y sin palabras vacias

# %%
dialogos= pd.read_csv('dialogos.csv')
dialogos2=dialogos

# %%
lista=[]
for i in range(0,959):
    lista.append(re.sub(r"[\W\d_]+", " ", dialogos.Locución.str.lower()[i]))
df = pd.DataFrame(columns=['lib'])
lista2=[]
lista1=[]
for i in range(959):
    lista1.append([palabra for palabra in lista[i].split() if palabra not in stopwords_sp])
    lista2=[lista1]
dialogos['Pre_procesado']=pd.DataFrame(lista2).T
dialogos
# Out:
#                                               Locución  \
# 0                                       Francamente no
# 1    Lo del canadiense. Por favor, como que vosotro...
# 2    Tienes razón. A lo mejor así te liberas de tu ...
# 3                                      Pues, tú sabrás
# 4                              Para mí que fue Krieger
# ..                                                 ...
# 954                        Yo qué sé, digo yo qué será
# 955  Lo han entendido mal. Las joyas que venden en ...
# 956                            Oooo... Me llamo Vivian
# 957                  ¿De dónde? ¿Del coño de tu madre?
# 958                       Ah, sí esto podría funcionar
#
#                                          Pre_procesado
# 0                                        [francamente]
# 1    [canadiense, favor, tiraríais, allí, si, pudie...
# 2      [razón, mejor, así, liberas, energía, nagativa]
# 3                                       [pues, sabrás]
# ...

# %%
dia=str(dialogos2.Locución.apply(str))
dia=dia.lower()

str(dia).split()



re.sub(r"[\W\d_]+", " ", dia)

dialogos3=dialogos.Locución.values
#dialogos3

####NO doy mas###
# Out:
# ' francamente no lo del canadiense por favor como que vosotro tienes razón a lo mejor así te liberas de tu pues tú sabrás para mí que fue krieger yo qué sé digo yo qué será lo han entendido mal las joyas que venden en oooo me llamo vivian de dónde del coño de tu madre ah sí esto podría funcionar name locución length dtype object'

# %%
with open("dialogos.csv", encoding = 'utF-8') as archivo1: 
    DIALOGOS = archivo1.read()

# %%
DIALOGOS = DIALOGOS.lower() # Minúscula
DIALOGOS = re.sub(r"[\W\d_]+", " ", DIALOGOS) # Dejar sólo letras
DIALOGOS = DIALOGOS.strip() # Quitar espacios del principio
DIALOGOS = DIALOGOS.split() # Tokenización
#DIALOGOS

# %%
DIALOGOS_ = [palabra for palabra in DIALOGOS if palabra not in stopwords_sp]
DIALOGOS_
DIALOGOS_
# Out:
# ['locución',
#  'francamente',
#  'canadiense',
#  'favor',
#  'tiraríais',
#  'allí',
#  'si',
#  'pudieseis',
#  'razón',
#  'mejor',
#  'así',
#  'liberas',
#  'energía',
#  'nagativa',
#  'pues',
#  'sabrás',
#  'krieger',
#  'bebé',
#  'lando',
#  'serio',
#  'randy',
#  'creo',
#  'deporte',
#  'hizo',
#  'daño',
#  'cerebro',
#  'estáte',
#  'quieto',
#  'esperad',
#  'parecido',
#  'archer',
#  'asustado',
#  'usted',
#  'jode',
#  'carajo',
#  'dios',
#  'pibe',
#  'oigo',
#  'claro',
#  'fuma',
#  'junto',
#  'niña',
#  'decir',
#  'robotizado',
#  'dónde',
#  'coño',
#  'sacado',
#  'mano',
#  'biónica',
#  'pues',
#  'venga',
#  'subid',
#  'atrás',
#  'avión',
#  'esperando',
#  'recordadme',
#  'si',
#  'desgraciado',
#  'mata',
#  'haga',
#  'jodas',
#  'cyril',
#  'haces',
#  'ventana',
#  'pues',
#  'existe',
#  'refrán',
#  'hindu',
#  'dice',
#  'fundió',
#  'generó',
#  'corten',
#  'perdón',
#  'voy',
#  'nuevo',
#  'intento',
#  'decir',
#  'deberíamos',
# ...

# %% [markdown]
# # Punto 2: Representación vectorial
#
# - `[11 pts]` Crear una bolsa de palabras (BoW) del corpus usando la columna pre-procesada
# - `[11 pts]` ¿Cuántas palabras hay en el vocabulario? (Usando la función de `sklearn`)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
bow_rep = count_vect.fit_transform(DIALOGOS_)
 
print(f"Vocabulario: {count_vect.vocabulary_}")
# Out:
# Vocabulario: {'locución': 1176, 'francamente': 822, 'canadiense': 274, 'favor': 803, 'tiraríais': 1940, 'allí': 63, 'si': 1818, 'pudieseis': 1598, 'razón': 1661, 'mejor': 1237, 'así': 133, 'liberas': 1115, 'energía': 696, 'nagativa': 1310, 'pues': 1606, 'sabrás': 1743, 'krieger': 1092, 'bebé': 184, 'lando': 1101, 'serio': 1805, 'randy': 1656, 'creo': 474, 'deporte': 580, 'hizo': 959, 'daño': 539, 'cerebro': 315, 'estáte': 770, 'quieto': 1642, 'esperad': 749, 'parecido': 1431, 'archer': 110, 'asustado': 130, 'usted': 2005, 'jode': 1052, 'carajo': 288, 'dios': 624, 'pibe': 1498, 'oigo': 1385, 'claro': 349, 'fuma': 835, 'junto': 1080, 'niña': 1337, 'decir': 552, 'robotizado': 1722, 'dónde': 668, 'coño': 458, 'sacado': 1749, 'mano': 1211, 'biónica': 197, 'venga': 2035, 'subid': 1871, 'atrás': 139, 'avión': 152, 'esperando': 751, 'recordadme': 1671, 'desgraciado': 595, 'mata': 1224, 'haga': 929, 'jodas': 1051, 'cyril': 515, 'haces': 925, 'ventana': 2041, 'existe': 784, 'refrán': 1685, 'hi
# ...

# %% [markdown]
# # Punto 3: 🤔
#
# - `[3pts]` ¿En qué casos es buena idea tomar en la cuenta la frecuencia de las palabras para la bolsa de palabras?
#
# - Respuesta: En el caso en que sea un texto con poco número de palabras se recomendaria usar la frecuencia de palabras;
# - Cuando sea un numero de palabras considerable se recomendaría bolsa de palabras
#
#
# - `[3pts]` ¿Cuándo es una mejor idea usar una bolsa de n-gramas en vez de una bolsa de palabras?
# - Respuesta cuando haya unión de palabras de interes, tales como 'Tabla Periodica', 'Coca Cola'

# %% [markdown]
# # BONUS Punto 4: 😜
#
# - `[1pt]` ¿A qué pertenecen los dialogos del primer punto?
# - No sé ,  podría ser una llamada telefonica, o una intercepción ilegal por parte del Gobierno, pero no lo es, la profesora nunca tendria contacto con algo ilegal.
